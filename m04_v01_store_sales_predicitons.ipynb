# %% [markdown]
# # 0.0 - IMPORTS

# %%
import math
import numpy as np
import pandas as pd
import inflection
import datetime

import seaborn as sns

from matplotlib import pyplot as plt
plt.style.use('Solarize_Light2')

from IPython.core.display import HTML
from IPython.display import Image

# %% [markdown]
# ## 0.1 Helper Functions

# %% [markdown]
# ## 0.2 Loading Data

# %%
df_sales_raw = pd.read_csv('data/train.csv', low_memory=False)
df_store_raw = pd.read_csv('data/store.csv', low_memory=False)

#merge
df_raw = pd.merge( df_sales_raw, df_store_raw, how ='left', on ='Store' )

# %%
df_raw.sample(2)
# Out:
#         Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 698217   1013          1  2013-10-14   3705        451     1      0
# 427052    793          6  2014-06-14   4473        452     1      0
#
#        StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 698217            0              0         a          a                630.0
# 427052            0              0         d          a               2710.0
#
#         CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 698217                        2.0                    2015.0       1
# 427052                        7.0                    2006.0       0
#
#         Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 698217             31.0           2013.0  Feb,May,Aug,Nov
# 427052              NaN              NaN              NaN

# %% [markdown]
# # 1.0 - Passo 01 - DESCRIÇÃO DOS DADOS

# %% [markdown]
# ## Data fields
# ### Most of the fields are self-explanatory. The following are descriptions for those that aren't.
#
# Id - an Id that represents a (Store, Date) duple within the test set
#
# Store - a unique Id for each store
#
# Sales - the turnover for any given day (this is what you are predicting)
#
# Customers - the number of customers on a given day
#
# Open - an indicator for whether the store was open: 0 = closed, 1 = open
#
# StateHoliday - indicates a state holiday. Normally all stores, with few exceptions, are closed on state holidays.
# Note that all schools are closed on public holidays and weekends.
# a = public holiday, b = Easter holiday, c = Christmas, 0 = None
#
# SchoolHoliday - indicates if the (Store, Date) was affected by the closure of public schools
#
# StoreType - differentiates between 4 different store models: a, b, c, d
#
# Assortment - describes an assortment level: a = basic, b = extra, c = extended
#
# CompetitionDistance - distance in meters to the nearest competitor store
#
# CompetitionOpenSince[Month/Year] - gives the approximate year and month of the time the nearest competitor was opened
#
# Promo - indicates whether a store is running a promo on that day
#
# Promo2 - Promo2 is a continuing and consecutive promotion for some stores: 0 = store is not participating,
# 1 = store is participating
#
# Promo2Since[Year/Week] - describes the year and calendar week when the store started participating in Promo2
#
# PromoInterval - describes the consecutive intervals Promo2 is started, naming the months the promotion is started anew
#
# E.g. "Feb,May,Aug,Nov" means each round starts in February, May, August, November of any given year for that store

# %%
df1 = df_raw.copy() #copio o DataFrame para esse bloco

# %% [markdown]
# ## 1.1 Rename Columns

# %%
df1.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
old_columns = ['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo', 'StateHoliday',
               'SchoolHoliday', 'StoreType', 'Assortment','CompetitionDistance', 'CompetitionOpenSinceMonth',
               'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek','Promo2SinceYear', 'PromoInterval']

snakecase = lambda x: inflection.underscore(x)

new_columns = list(map(snakecase, old_columns))

#rename
df1.columns = new_columns

# %%
df1.columns
# Out:
# Index(['store', 'day_of_week', 'date', 'sales', 'customers', 'open', 'promo',
#        'state_holiday', 'school_holiday', 'store_type', 'assortment',
#        'competition_distance', 'competition_open_since_month',
#        'competition_open_since_year', 'promo2', 'promo2_since_week',
#        'promo2_since_year', 'promo_interval'],
#       dtype='object')

# %% [markdown]
# ## 1.2 Data Dimensions

# %%
#Qual a qtd de linhas e colunas do dataset
print(f'Number of Rows: {df1.shape[0]}')
print(f'Number of Columns: {df1.shape[1]}')
# Out:
# Number of Rows: 1017209
# Number of Columns: 18

# %% [markdown]
# ## 1.3 Data Types

# %%
df1.dtypes
# Out:
# store                             int64
# day_of_week                       int64
# date                             object
# sales                             int64
# customers                         int64
# open                              int64
# promo                             int64
# state_holiday                    object
# school_holiday                    int64
# store_type                       object
# assortment                       object
# competition_distance            float64
# competition_open_since_month    float64
# competition_open_since_year     float64
# promo2                            int64
# promo2_since_week               float64
# promo2_since_year               float64
# promo_interval                   object
# dtype: object

# %%
#A coluna date era object e vamos mudá-la para formato de data
df1['date'] = pd.to_datetime(df1['date'])

# %%
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# dtype: object

# %% [markdown]
# ## 1.4 Check NA

# %%
df1.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %% [markdown]
# ## 1.5 Fillout NA

# %% [markdown]
# ### Os NA precisam ser tratados.
# #### 1) Jogar essas linhas fora -> VTG: rápido e fácil | DVG: jogar dado fora, pode prejudicar a performance do modelo
# #### 2) Usando métodos de ML para substituir as linhas NA pelo comportamento da coluna (mediana, média, previsões)
# #### 3) Entendendo o negócio. Pq esse NA está aqui?
#
# #### Vamos tratar pelo método 3 cada coluna com NA.
# #### competition_distance
# #### competition_open_since_month
# #### competition_open_since_year
# #### promo2_since_week
# #### promo2_since_year
# #### promo_interval

# %%
#------------------------------------------------------------------------------------
#competition_distance
#------------------------------------------------------------------------------------
#se tem NA é porque não tem competidor próximo (assumption) => usar o método isnan da classe math
#esse método vai me dizer se nesa linha da coluna competition_distance o valor é NA.
#vamos substituir o valor onde for NA por um valor muito grande!!!

#encontrando o valor máximo de competition_distance 75860.0
#df1['competition_distance'].max()

#Logo vamos admitir um valor bem alto 200000.0 para as linhas com valor NA, substituindo df1 por x
#para aplicar essa função em todas as linhas, usar o método apply
#Terei que especificar em qual coluna será aplicada a função, posso retirar do interior o ['competition_distance']
#O resultado dessa função quero sobreescrever os resultados originais
df1['competition_distance'] = df1['competition_distance'].apply(lambda x: 200000 if math.isnan(x) else x)

# %%
#------------------------------------------------------------------------------------
#competition_open_since_month & competition_open_since_year
#------------------------------------------------------------------------------------
#se tem NA é porque ou não tem competidor ou esqueceram de lançar o mês de que ele chegou
#colocar o mês da venda como mês do competidor (assumption) => usar o método isnan da classe math
#primeiro ver se ela é NA, com o método isnan, e fazer uma condição
#se isso for vdd vou extrair o mês da coluna date e colocar nela
#se não for vdd eu retorno o valor (depois do else)
#chamando a função lambda eu posso substituir o df1
#axis=1 pois tenho mais de uma coluna e preciso explicitar que a ação será em cada linha ao longo das colunas
#quero que o resultado sobreescreva a coluna original competition_open_since_month
df1['competition_open_since_month'] = df1.apply(lambda x: x['date'].month if math.isnan(x['competition_open_since_month']) else x['competition_open_since_month'], axis=1)


#mesmo raciocício para competition_open_since_year, porém extraindo o ano
df1['competition_open_since_year'] = df1.apply(lambda x: x['date'].year if math.isnan(x['competition_open_since_year']) else x['competition_open_since_year'], axis=1)


#mesmo raciocício para promo2_since_week, porém extraindo a semana
df1['promo2_since_week'] = df1.apply(lambda x: x['date'].week if math.isnan(x['promo2_since_week']) else x['promo2_since_week'], axis=1)


#mesmo raciocício para promo2_since_year, porém extraindo o ano
df1['promo2_since_year'] = df1.apply(lambda x: x['date'].year if math.isnan(x['promo2_since_year']) else x['promo2_since_year'], axis=1)

# %%
#------------------------------------------------------------------------------------
#promo_interval
#------------------------------------------------------------------------------------
#Criar uma coluna auxiliar para trabalhar os dados
month_map = {1:'Jan', 2:'Fev', 3:'Mar', 4:'Apr', 5:'Mai', 6:'Jun',
             7:'Jul', 8:'Aug', 9:'Sept', 10:'Oct', 11:'Nov', 12:'Dec'}

df1['promo_interval'].fillna(0, inplace=True)

df1['month_map'] = df1['date'].dt.month.map(month_map)


df1['is_promo'] = df1[['promo_interval', 'month_map']].apply(lambda x: 0 if x['promo_interval'] == 0
                                                             else 1 if x['month_map'] in x['promo_interval'].split(',')
                                                             else 0, axis = 1)

# %%
df1.sample(5).T
# Out:
#                                            141133               684692  \
# store                                         644                  868
# day_of_week                                     5                    6
# date                          2015-03-27 00:00:00  2013-10-26 00:00:00
# sales                                       10465                 8775
# customers                                    1119                  642
# open                                            1                    1
# promo                                           0                    0
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      c                    d
# assortment                                      a                    c
# competition_distance                         4030                 1360
# competition_open_since_month                   12                    8
# competition_open_since_year                  2004                 2005
# promo2                                          1                    1
# promo2_since_week                              14                   10
# promo2_since_year                            2011                 2014
# promo_interval                    Jan,Apr,Jul,Oct      Jan,Apr,Jul,Oct
# month_map                                     Mar                  Oct
# is_promo                                        0                    1
#
#                                            3940                 557908  \
# store                                         596                   79
# day_of_week                                     2                    7
# date                          2015-07-28 00:00:00  2014-02-16 00:00:00
# sales                                        6347                    0
# customers                                     864                    0
# open                                            1                    0
# promo                                           1                    0
# state_holiday                                   0                    0
# school_holiday                                  1                    0
# store_type                                      c                    a
# assortment                                      a                    a
# competition_distance                          290                 3320
# competition_open_since_month                    9                    2
# competition_open_since_year                  2006                 2014
# promo2                                          0                    0
# promo2_since_week                              31                    7
# promo2_since_year                            2015                 2014
# promo_interval                                  0                    0
# month_map                                     Jul                  Fev
# is_promo                                        0                    0
#
#                                            445277
# store                                          63
# day_of_week                                     3
# date                          2014-05-28 00:00:00
# sales                                        7696
# customers                                     747
# open                                            1
# promo                                           0
# state_holiday                                   0
# school_holiday                                  0
# store_type                                      c
# assortment                                      c
# competition_distance                         3700
# competition_open_since_month                    6
# competition_open_since_year                  2010
# promo2                                          1
# promo2_since_week                              18
# promo2_since_year                            2010
# promo_interval                    Feb,May,Aug,Nov
# month_map                                     Mai
# is_promo                                        0

# %% [markdown]
# ## 1.6 Check Types

# %%
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# month_map                               object
# is_promo                                 int64
# dtype: object

# %%
#Alterar os float para int
df1['competition_open_since_month'] = df1['competition_open_since_month'].astype(int)
df1['competition_open_since_year'] = df1['competition_open_since_year'].astype(int)
df1['promo2_since_week'] = df1['promo2_since_week'].astype(int)
df1['promo2_since_year'] = df1['promo2_since_year'].astype(int)

# %%
#Checar as alterações
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month             int64
# competition_open_since_year              int64
# promo2                                   int64
# promo2_since_week                        int64
# promo2_since_year                        int64
# promo_interval                          object
# month_map                               object
# is_promo                                 int64
# dtype: object

# %%
#Checar se ainda tem algum NA
df1.isna().sum()
# Out:
# store                           0
# day_of_week                     0
# date                            0
# sales                           0
# customers                       0
# open                            0
# promo                           0
# state_holiday                   0
# school_holiday                  0
# store_type                      0
# assortment                      0
# competition_distance            0
# competition_open_since_month    0
# competition_open_since_year     0
# promo2                          0
# promo2_since_week               0
# promo2_since_year               0
# promo_interval                  0
# month_map                       0
# is_promo                        0
# dtype: int64

# %%
#Qual a qtd de linhas e colunas do dataset
print(f'Number of Rows: {df1.shape[0]}')
print(f'Number of Columns: {df1.shape[1]}')
# Out:
# Number of Rows: 1017209
# Number of Columns: 20

# %% [markdown]
# ## 1.7 Statistical Descriptive

# %%
#Entender o negócio
#Conseguir detectar erros -> Métricas de dispersão (desvio padrão, variância, mín, máx, range, skew e kurtosis)
#e de tendência central (médias e medianas)
#skew: como que a deformação da minha distribuição em relação a normal
#kurtose: fala sobre a concentração dos dados

# %%
num_attributes = df1.select_dtypes(include=['int64', 'float64'])
cat_attributes = df1.select_dtypes(exclude=['int64', 'float64', 'datetime64[ns]'])

# %% [markdown]
# ### 1.7.1 Numerical Attributes

# %%
#Central Tendency (mean, median)
ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

#Dispersion (std, min, max, var, skew, kurtosis)
d1 = pd.DataFrame(num_attributes.apply(np.std)).T
d2 = pd.DataFrame(num_attributes.apply(min)).T
d3 = pd.DataFrame(num_attributes.apply(max)).T
d4 = pd.DataFrame(num_attributes.apply(lambda x: x.max() - x.min())).T
d5 = pd.DataFrame(num_attributes.apply(lambda x: x.skew())).T
d6 = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis())).T

#concatenate
m = pd.concat([d2, d3, d4, ct1, ct2, d1, d5, d6]).T.reset_index()
m.columns = ['attributes', 'min', 'max', 'range', 'media', 'mediana', 'std', 'skew', 'kurtosis']
m
# Out:
#                       attributes     min       max     range        media  \
# 0                          store     1.0    1115.0    1114.0   558.429727
# 1                    day_of_week     1.0       7.0       6.0     3.998341
# 2                          sales     0.0   41551.0   41551.0  5773.818972
# 3                      customers     0.0    7388.0    7388.0   633.145946
# 4                           open     0.0       1.0       1.0     0.830107
# 5                          promo     0.0       1.0       1.0     0.381515
# 6                 school_holiday     0.0       1.0       1.0     0.178647
# 7           competition_distance    20.0  200000.0  199980.0  5935.442677
# 8   competition_open_since_month     1.0      12.0      11.0     6.786849
# 9    competition_open_since_year  1900.0    2015.0     115.0  2010.324840
# 10                        promo2     0.0       1.0       1.0     0.500564
# 11             promo2_since_week     1.0      52.0      51.0    23.619033
# 12             promo2_since_year  2009.0    2015.0       6.0  2012.793297
# 13                      is_promo     0.0       1.0       1.0     0.149214
#
#     mediana           std       skew    kurtosis
# 0     558.0    321.908493  -0.000955   -1.200524
# 1       4.0      1.997390   0.001593   -1.246873
# 2    5744.0   3849.924283   0.641460    1.778375
# 3     609.0    464.411506   1.598650    7.091773
# 4       1.0      0.375539  -1.758045    1.090723
# 5       0.0      0.485758   0.487838   -1.762018
# 6       0.0      0.383056   1.677842    0.815154
# 7    2330.0  12547.646829  10.242344  147.789712
# 8       7.0      3.311085  -0.042076   -1.232607
# 9    2012.0      5.515591  -7.235657  124.071304
# 10      1.0      0.500000  -0.002255   -1.999999
# 11     22.0     14.310057   0.178723   -1.184046
# 12   2013.0      1.662657  -0.784436   -0.210075
# 13      0.0      0.356299   1.969053    1.877175

# %%
sns.distplot(df1['customers'])

# %% [markdown]
# ### 1.7.2 Categorical Attributes

# %%
cat_attributes.apply(lambda x: x.unique().shape[0])
# Out:
# state_holiday      4
# store_type         4
# assortment         3
# promo_interval     4
# month_map         12
# dtype: int64

# %%
aux1 = df1[(df1['state_holiday'] != '0') & (df1['sales'] > 0)]

plt.subplot(1, 3, 1)
sns.boxplot(x='state_holiday' , y='sales' , data=aux1 )

plt.subplot(1, 3, 2)
sns.boxplot(x='store_type' , y='sales' , data=aux1 )

plt.subplot(1, 3, 3)
sns.boxplot(x='assortment' , y='sales' , data=aux1 )

# %% [markdown]
# # 2.0 - Passo 02 - FEATURE ENGINEERING

# %%
#copiar os dados para seção 2.0
df2 = df1.copy()

# %% [markdown]
# ## 2.1 Mapa mental das hipóteses

# %%
Image('img/Mind-Maps-Hipotesis.png')

# %% [markdown]
# ## 2.2 Hypotesis Creation

# %% [markdown]
# Blá blá blá + [APOSTA] + {ATRIBUTO DO MIND MAP} + **deveriam** + {VARIÁVEL RESPOSTA QUE SERÁ MODELADA} + [APOSTA]

# %% [markdown]
# ### 2.2.1 Hipóteses das Lojas

# %% [markdown]
# **1.** Lojas com MAIOR quadro de **funcionários** deveriam **vender** MAIS.
#
# **2.** Lojas com MAIOR **estoque** deveriam **vender** MAIS.
#
# **3.** Lojas com MAIOR **porte** deveriam **vender** MAIS.
#
# **4.** Lojas com MENOR **porte** deveriam **vender** MENOS.
#
# **5.** Lojas com MAIOR **sortimento** deveriam **vender** MAIS.

# %% [markdown]
# ### 2.2.2 Hipóteses Produto

# %% [markdown]
# **1.** Lojas com MAIOR investimento em **marketing** deveriam **vender** MAIS.
#
# **2.** Lojas com MAIOR **exposição** deveriam **vender** MAIS.
#
# **3.** Lojas com MENOR **preço** deveriam **vender** MAIS.
#
# **4.** Lojas com MAIOR **promoção** deveriam **vender** MAIS.

# %% [markdown]
# ### 2.2.3 Hipóteses Tempo (Sazonalidade)

# %% [markdown]
# **1.** Lojas com MAIOR número de **feriado** deveriam **vender** MENOS.
#
# **2.** Lojas NOS PRIMEIROS 06 **meses** deveriam **vender** MAIS.
#
# **3.** Lojas que ABREM MAIS **dias** deveriam **vender** MAIS.

# %% [markdown]
# São apostas, não relação de causa e efeito mas sim encontrar a correlação (se houver) entre os atributos e a minha variável resposta, que será modelada...

# %% [markdown]
# ## 2.3 Lista Final de Hipóteses

# %% [markdown]
# ### As hipóteses que comporão essa lista serão priorizadas  e separadas com base nas informação que já exstentem, que permitam verificar a "APOSTA" feita....

# %% [markdown]
# **1.** Lojas com MAIOR **sortimentos** deveriam **vender** MAIS.
#
# **2.** Lojas com **competidores** MAIS PRÓXIMOS deveriam **vender** MAIS.
#
# **3.** Lojas com **competidores** À MAIS TEMPO deveriam **vender** MAIS.
#
# **4.** Lojas com **promoção** À MAIS TEMPO deveriam **vender** MAIS.
#
# **5.** Lojas com MAIS dias de **promoção** deveriam **vender** MAIS.
#
# **6.** Lojas com MAIS **promoção** consecutiva deveriam **vender** MAIS.
#
# **7.** Lojas ABERTAS **feriado de Natal** deveriam **vender** MAIS.
#
# **8.** Lojas AO LONGO do **ano** deveriam **vender** MAIS.
#
# **9.** Lojas no SEGUNDO **semestre** deveriam **vender** MAIS.
#
# **10.** Lojas DEPOIS DO DÉCIMO **dia** deveriam **vender** MAIS.
#
# **11.** Lojas ABERTAS no **final de semana** deveriam **vender** MENOS.
#
# **12.** Lojas ABERTAS no **feriado escolar** deveriam **vender** MENOS.

# %% [markdown]
# ## 2.4 Feature Engineering

# %%
#Derivação da coluna date:
#year
df2['year'] = df2['date'].dt.year

#month
df2['month'] = df2['date'].dt.month

#day
df2['day'] = df2['date'].dt.day

#week_year
df2['week_year'] = df2['date'].dt.weekofyear

#year_week
df2['year_week'] = df2['date'].dt.strftime('%Y-%W')

#competition since
#promo since

#assortment
#state_holiday

# %%
df2.sample(5).T #Vê as colunas year, month, day, week_year e year_week
# Out:
#                                            346206               648156  \
# store                                         515                   12
# day_of_week                                     5                    3
# date                          2014-09-05 00:00:00  2013-11-27 00:00:00
# sales                                       11116                 7964
# customers                                     887                  879
# open                                            1                    1
# promo                                           1                    0
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      d                    a
# assortment                                      c                    c
# competition_distance                        11260                 1070
# competition_open_since_month                    9                   11
# competition_open_since_year                  2014                 2013
# promo2                                          1                    1
# promo2_since_week                               9                   13
# promo2_since_year                            2011                 2010
# promo_interval                    Feb,May,Aug,Nov      Jan,Apr,Jul,Oct
# month_map                                    Sept                  Nov
# is_promo                                        0                    0
# year                                         2014                 2013
# month                                           9                   11
# day                                             5                   27
# week_year                                      36                   48
# year_week                                 2014-35              2013-47
#
#                                            206623               937180  \
# store                                         349                  251
# day_of_week                                     2                    3
# date                          2015-01-27 00:00:00  2013-03-13 00:00:00
# sales                                        7782                16568
# customers                                     816                 2237
# open                                            1                    1
# promo                                           1                    0
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      c                    a
# assortment                                      c                    c
# competition_distance                         1490                  340
# competition_open_since_month                    4                    3
# competition_open_since_year                  2009                 2013
# promo2                                          0                    0
# promo2_since_week                               5                   11
# promo2_since_year                            2015                 2013
# promo_interval                                  0                    0
# month_map                                     Jan                  Mar
# is_promo                                        0                    0
# year                                         2015                 2013
# month                                           1                    3
# day                                            27                   13
# week_year                                       5                   11
# year_week                                 2015-04              2013-10
#
#                                            954410
# store                                         756
# day_of_week                                     2
# date                          2013-02-26 00:00:00
# sales                                       11243
# customers                                    1659
# open                                            1
# promo                                           0
# state_holiday                                   0
# school_holiday                                  0
# store_type                                      a
# assortment                                      c
# competition_distance                           50
# competition_open_since_month                    2
# competition_open_since_year                  2013
# promo2                                          1
# promo2_since_week                              40
# promo2_since_year                            2011
# promo_interval                    Jan,Apr,Jul,Oct
# month_map                                     Fev
# is_promo                                        0
# year                                         2013
# month                                           2
# day                                            26
# week_year                                       9
# year_week                                 2013-08

# %%
#competition since
#Preciso unir duas colunas para formar a data competition since e depois iterar com a date.
df2['competition_since'] = df2.apply(lambda x: datetime.datetime(year=x['competition_open_since_year'], month=x['competition_open_since_month'], day=1), axis=1)
df2['competition_time_month'] = ((df2['date'] - df2['competition_since']) / 30).apply(lambda x: x.days).astype(int)
#promo since

#assortment
#state_holiday

# %%
df2.sample(5).T #Vê as colunas competiton since e a coluna competition time month
# Out:
#                                            839402               850643  \
# store                                         593                  684
# day_of_week                                     7                    4
# date                          2013-06-09 00:00:00  2013-05-30 00:00:00
# sales                                           0                    0
# customers                                       0                    0
# open                                            0                    0
# promo                                           0                    1
# state_holiday                                   0                    a
# school_holiday                                  0                    1
# store_type                                      a                    d
# assortment                                      c                    c
# competition_distance                        33060                  680
# competition_open_since_month                    3                    5
# competition_open_since_year                  2010                 2013
# promo2                                          0                    1
# promo2_since_week                              23                   22
# promo2_since_year                            2013                 2012
# promo_interval                                  0      Jan,Apr,Jul,Oct
# month_map                                     Jun                  Mai
# is_promo                                        0                    0
# year                                         2013                 2013
# month                                           6                    5
# day                                             9                   30
# week_year                                      23                   22
# year_week                                 2013-22              2013-21
# competition_since             2010-03-01 00:00:00  2013-05-01 00:00:00
# competition_time_month                         39                    0
#
#                                            563101               773860  \
# store                                         812                  836
# day_of_week                                     3                    3
# date                          2014-02-12 00:00:00  2013-08-07 00:00:00
# sales                                        5615                 4731
# customers                                     741                  652
# open                                            1                    1
# promo                                           0                    0
# state_holiday                                   0                    0
# school_holiday                                  0                    1
# store_type                                      d                    a
# assortment                                      a                    a
# competition_distance                         2590                 2720
# competition_open_since_month                    9                    9
# competition_open_since_year                  2012                 2012
# promo2                                          0                    0
# promo2_since_week                               7                   32
# promo2_since_year                            2014                 2013
# promo_interval                                  0                    0
# month_map                                     Fev                  Aug
# is_promo                                        0                    0
# year                                         2014                 2013
# month                                           2                    8
# day                                            12                    7
# week_year                                       7                   32
# year_week                                 2014-06              2013-31
# competition_since             2012-09-01 00:00:00  2012-09-01 00:00:00
# competition_time_month                         17                   11
#
#                                            612309
# store                                         960
# day_of_week                                     1
# date                          2013-12-30 00:00:00
# sales                                        8511
# customers                                     737
# open                                            1
# promo                                           0
# state_holiday                                   0
# school_holiday                                  1
# store_type                                      d
# assortment                                      a
# competition_distance                         8990
# competition_open_since_month                   12
# competition_open_since_year                  2013
# promo2                                          1
# promo2_since_week                              31
# promo2_since_year                            2009
# promo_interval                    Feb,May,Aug,Nov
# month_map                                     Dec
# is_promo                                        0
# year                                         2013
# month                                          12
# day                                            30
# week_year                                       1
# year_week                                 2013-52
# competition_since             2013-12-01 00:00:00
# competition_time_month                          0

# %%
#promo since
#Também precisarei unir informações de duas colunas, porém a dificuldade é que as informações são week e year
#1) Fazer o join dessas informações para ter uma única data
#Faz o join dos caracteres e depois transforma em data
df2['promo_since'] = df2['promo2_since_year'].astype(str) + '-' + df2['promo2_since_week'].astype(str)
df2['promo_since'] = df2['promo_since'].apply(lambda x: datetime.datetime.strptime(x + '-1', '%Y-%W-%w') - datetime.timedelta(days=7))
df2['promo_time_week'] = ((df2['date'] - df2['promo_since']) / 7).apply(lambda x: x.days).astype(int)
#assortment
#state_holiday

# %%
df2.sample(5).T
# Out:
#                                            980731               541672  \
# store                                         317                  568
# day_of_week                                     6                    1
# date                          2013-02-02 00:00:00  2014-03-03 00:00:00
# sales                                        7109                 5906
# customers                                     764                  503
# open                                            1                    1
# promo                                           0                    1
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      d                    d
# assortment                                      a                    c
# competition_distance                         3140                 4270
# competition_open_since_month                    7                    3
# competition_open_since_year                  2013                 2014
# promo2                                          1                    1
# promo2_since_week                              14                    1
# promo2_since_year                            2011                 2013
# promo_interval                    Jan,Apr,Jul,Oct      Jan,Apr,Jul,Oct
# month_map                                     Fev                  Mar
# is_promo                                        0                    0
# year                                         2013                 2014
# month                                           2                    3
# day                                             2                    3
# week_year                                       5                   10
# year_week                                 2013-04              2014-09
# competition_since             2013-07-01 00:00:00  2014-03-01 00:00:00
# competition_time_month                         -5                    0
# promo_since                   2011-03-28 00:00:00  2012-12-31 00:00:00
# promo_time_week                                96                   61
#
#                                            237772               729899  \
# store                                         548                  360
# day_of_week                                     2                    7
# date                          2014-12-30 00:00:00  2013-09-15 00:00:00
# sales                                        5231                    0
# customers                                     409                    0
# open                                            1                    0
# promo                                           0                    0
# state_holiday                                   0                    0
# school_holiday                                  1                    0
# store_type                                      d                    a
# assortment                                      c                    a
# competition_distance                         3760                 2040
# competition_open_since_month                    2                    6
# competition_open_since_year                  2009                 2007
# promo2                                          0                    0
# promo2_since_week                               1                   37
# promo2_since_year                            2014                 2013
# promo_interval                                  0                    0
# month_map                                     Dec                 Sept
# is_promo                                        0                    0
# year                                         2014                 2013
# month                                          12                    9
# day                                            30                   15
# week_year                                       1                   37
# year_week                                 2014-52              2013-36
# competition_since             2009-02-01 00:00:00  2007-06-01 00:00:00
# competition_time_month                         71                   76
# promo_since                   2013-12-30 00:00:00  2013-09-09 00:00:00
# promo_time_week                                52                    0
#
#                                            368378
# store                                         205
# day_of_week                                     2
# date                          2014-08-12 00:00:00
# sales                                        5052
# customers                                     775
# open                                            1
# promo                                           0
# state_holiday                                   0
# school_holiday                                  1
# store_type                                      a
# assortment                                      a
# competition_distance                          110
# competition_open_since_month                   12
# competition_open_since_year                  2007
# promo2                                          0
# promo2_since_week                              33
# promo2_since_year                            2014
# promo_interval                                  0
# month_map                                     Aug
# is_promo                                        0
# year                                         2014
# month                                           8
# day                                            12
# week_year                                      33
# year_week                                 2014-32
# competition_since             2007-12-01 00:00:00
# competition_time_month                         81
# promo_since                   2014-08-11 00:00:00
# promo_time_week                                 0

# %%
#assortment -> describes an assortment level: a = basic, b = extra, c = extended
df2['assortment'] = df2['assortment'].apply(lambda x: 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended')

# %%
df2.sample(5).T
# Out:
#                                            694187               314873  \
# store                                         328                 1060
# day_of_week                                     4                    4
# date                          2013-10-17 00:00:00  2014-10-09 00:00:00
# sales                                        3805                 7250
# customers                                     479                  864
# open                                            1                    1
# promo                                           0                    1
# state_holiday                                   0                    0
# school_holiday                                  0                    1
# store_type                                      a                    a
# assortment                                  basic             extended
# competition_distance                         3130                 3430
# competition_open_since_month                    7                   10
# competition_open_since_year                  2002                 2014
# promo2                                          0                    1
# promo2_since_week                              42                   31
# promo2_since_year                            2013                 2013
# promo_interval                                  0      Feb,May,Aug,Nov
# month_map                                     Oct                  Oct
# is_promo                                        0                    0
# year                                         2013                 2014
# month                                          10                   10
# day                                            17                    9
# week_year                                      42                   41
# year_week                                 2013-41              2014-40
# competition_since             2002-07-01 00:00:00  2014-10-01 00:00:00
# competition_time_month                        137                    0
# promo_since                   2013-10-14 00:00:00  2013-07-29 00:00:00
# promo_time_week                                 0                   62
#
#                                            234553               372467  \
# store                                         404                  610
# day_of_week                                     5                    5
# date                          2015-01-02 00:00:00  2014-08-08 00:00:00
# sales                                        4547                 4501
# customers                                     512                  539
# open                                            1                    1
# promo                                           0                    1
# state_holiday                                   0                    0
# school_holiday                                  1                    1
# store_type                                      a                    a
# assortment                               extended                basic
# competition_distance                         1420                  660
# competition_open_since_month                    1                    1
# competition_open_since_year                  2015                 2007
# promo2                                          1                    0
# promo2_since_week                              10                   32
# promo2_since_year                            2013                 2014
# promo_interval                   Mar,Jun,Sept,Dec                    0
# month_map                                     Jan                  Aug
# is_promo                                        0                    0
# year                                         2015                 2014
# month                                           1                    8
# day                                             2                    8
# week_year                                       1                   32
# year_week                                 2015-00              2014-31
# competition_since             2015-01-01 00:00:00  2007-01-01 00:00:00
# competition_time_month                          0                   92
# promo_since                   2013-03-04 00:00:00  2014-08-04 00:00:00
# promo_time_week                                95                    0
#
#                                            769453
# store                                         889
# day_of_week                                     7
# date                          2013-08-11 00:00:00
# sales                                           0
# customers                                       0
# open                                            0
# promo                                           0
# state_holiday                                   0
# school_holiday                                  0
# store_type                                      d
# assortment                                  basic
# competition_distance                        18670
# competition_open_since_month                   12
# competition_open_since_year                  2005
# promo2                                          0
# promo2_since_week                              32
# promo2_since_year                            2013
# promo_interval                                  0
# month_map                                     Aug
# is_promo                                        0
# year                                         2013
# month                                           8
# day                                            11
# week_year                                      32
# year_week                                 2013-31
# competition_since             2005-12-01 00:00:00
# competition_time_month                         93
# promo_since                   2013-08-05 00:00:00
# promo_time_week                                 0

# %%
#state_holiday -> a = public holiday, b = Easter holiday, c = Christmas, 0 = None
df2['state_holiday'] = df2['state_holiday'].apply(lambda x: 'public holiday' if x == 'a' else 'Easter holiday' if x == 'b' else 'Christmas' if x == 'c' else 'regular day')

# %%
df2.sample(5).T
# Out:
#                                            323155               340469  \
# store                                         907                  366
# day_of_week                                     2                    4
# date                          2014-09-30 00:00:00  2014-09-11 00:00:00
# sales                                        8203                 5045
# customers                                    1002                  582
# open                                            1                    1
# promo                                           1                    0
# state_holiday                         regular day          regular day
# school_holiday                                  0                    0
# store_type                                      a                    d
# assortment                               extended             extended
# competition_distance                          250                 6470
# competition_open_since_month                    9                   12
# competition_open_since_year                  2014                 2004
# promo2                                          0                    0
# promo2_since_week                              40                   37
# promo2_since_year                            2014                 2014
# promo_interval                                  0                    0
# month_map                                    Sept                 Sept
# is_promo                                        0                    0
# year                                         2014                 2014
# month                                           9                    9
# day                                            30                   11
# week_year                                      40                   37
# year_week                                 2014-39              2014-36
# competition_since             2014-09-01 00:00:00  2004-12-01 00:00:00
# competition_time_month                          0                  119
# promo_since                   2014-09-29 00:00:00  2014-09-08 00:00:00
# promo_time_week                                 0                    0
#
#                                            987867               137092  \
# store                                         763                 1063
# day_of_week                                     7                    2
# date                          2013-01-27 00:00:00  2015-03-31 00:00:00
# sales                                           0                 7015
# customers                                       0                  652
# open                                            0                    1
# promo                                           0                    1
# state_holiday                         regular day          regular day
# school_holiday                                  0                    0
# store_type                                      d                    a
# assortment                               extended             extended
# competition_distance                        32240                 6250
# competition_open_since_month                    3                    3
# competition_open_since_year                  2010                 2015
# promo2                                          0                    0
# promo2_since_week                               4                   14
# promo2_since_year                            2013                 2015
# promo_interval                                  0                    0
# month_map                                     Jan                  Mar
# is_promo                                        0                    0
# year                                         2013                 2015
# month                                           1                    3
# day                                            27                   31
# week_year                                       4                   14
# year_week                                 2013-03              2015-13
# competition_since             2010-03-01 00:00:00  2015-03-01 00:00:00
# competition_time_month                         35                    1
# promo_since                   2013-01-21 00:00:00  2015-03-30 00:00:00
# promo_time_week                                 0                    0
#
#                                            929520
# store                                         396
# day_of_week                                     3
# date                          2013-03-20 00:00:00
# sales                                       11711
# customers                                    1195
# open                                            1
# promo                                           1
# state_holiday                         regular day
# school_holiday                                  0
# store_type                                      a
# assortment                               extended
# competition_distance                        23130
# competition_open_since_month                    3
# competition_open_since_year                  2013
# promo2                                          0
# promo2_since_week                              12
# promo2_since_year                            2013
# promo_interval                                  0
# month_map                                     Mar
# is_promo                                        0
# year                                         2013
# month                                           3
# day                                            20
# week_year                                      12
# year_week                                 2013-11
# competition_since             2013-03-01 00:00:00
# competition_time_month                          0
# promo_since                   2013-03-18 00:00:00
# promo_time_week                                 0

# %% [markdown]
# # 3.0 - Passo 03 - FILTRAGEM DE VARIÁVEIS

# %%
df3 = df2.copy()

# %%
df3.head().T
# Out:
#                                                 0                    1  \
# store                                           1                    2
# day_of_week                                     5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                        5263                 6064
# customers                                     555                  625
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular day          regular day
# school_holiday                                  1                    1
# store_type                                      c                    a
# assortment                                  basic                basic
# competition_distance                         1270                  570
# competition_open_since_month                    9                   11
# competition_open_since_year                  2008                 2007
# promo2                                          0                    1
# promo2_since_week                              31                   13
# promo2_since_year                            2015                 2010
# promo_interval                                  0      Jan,Apr,Jul,Oct
# month_map                                     Jul                  Jul
# is_promo                                        0                    1
# year                                         2015                 2015
# month                                           7                    7
# day                                            31                   31
# week_year                                      31                   31
# year_week                                 2015-30              2015-30
# competition_since             2008-09-01 00:00:00  2007-11-01 00:00:00
# competition_time_month                         84                   94
# promo_since                   2015-07-27 00:00:00  2010-03-22 00:00:00
# promo_time_week                                 0                  279
#
#                                                 2                    3  \
# store                                           3                    4
# day_of_week                                     5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                        8314                13995
# customers                                     821                 1498
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular day          regular day
# school_holiday                                  1                    1
# store_type                                      a                    c
# assortment                                  basic             extended
# competition_distance                        14130                  620
# competition_open_since_month                   12                    9
# competition_open_since_year                  2006                 2009
# promo2                                          1                    0
# promo2_since_week                              14                   31
# promo2_since_year                            2011                 2015
# promo_interval                    Jan,Apr,Jul,Oct                    0
# month_map                                     Jul                  Jul
# is_promo                                        1                    0
# year                                         2015                 2015
# month                                           7                    7
# day                                            31                   31
# week_year                                      31                   31
# year_week                                 2015-30              2015-30
# competition_since             2006-12-01 00:00:00  2009-09-01 00:00:00
# competition_time_month                        105                   71
# promo_since                   2011-03-28 00:00:00  2015-07-27 00:00:00
# promo_time_week                               226                    0
#
#                                                 4
# store                                           5
# day_of_week                                     5
# date                          2015-07-31 00:00:00
# sales                                        4822
# customers                                     559
# open                                            1
# promo                                           1
# state_holiday                         regular day
# school_holiday                                  1
# store_type                                      a
# assortment                                  basic
# competition_distance                        29910
# competition_open_since_month                    4
# competition_open_since_year                  2015
# promo2                                          0
# promo2_since_week                              31
# promo2_since_year                            2015
# promo_interval                                  0
# month_map                                     Jul
# is_promo                                        0
# year                                         2015
# month                                           7
# day                                            31
# week_year                                      31
# year_week                                 2015-30
# competition_since             2015-04-01 00:00:00
# competition_time_month                          4
# promo_since                   2015-07-27 00:00:00
# promo_time_week                                 0

# %% [markdown]
# ## 3.1 Filtragem das Linhas

# %% [markdown]
# ### Quero excluir as linhas onde a loja está fechada e as vendas sejam igual a zero

# %%
# open != 0
# sales > 0
df3 = df3[(df3['open'] != 0) & (df3['sales'] > 0)]

# %% [markdown]
# ## 3.2 Seleção das Colunas

# %%
#coluna customers: quantos clientes tinham naquela loja nesse dia que fizeram essas compras.
#Não tenho quantos terão daqui a seis semanas. Teria que fazer um projeto a parte.
#Restrição de negócio, não tenho ela no momento da predição
#devo retirar as colunas open, por só ter agora valores igual a 1;
#e as colunas que eu já derivei seus valores: promo_interval e month_map
cols_drop = ['customers', 'open', 'promo_interval', 'month_map']
df3 = df3.drop(cols_drop, axis = 1)

# %%
df3.columns
# Out:
# Index(['store', 'day_of_week', 'date', 'sales', 'promo', 'state_holiday',
#        'school_holiday', 'store_type', 'assortment', 'competition_distance',
#        'competition_open_since_month', 'competition_open_since_year', 'promo2',
#        'promo2_since_week', 'promo2_since_year', 'is_promo', 'year', 'month',
#        'day', 'week_year', 'year_week', 'competition_since',
#        'competition_time_month', 'promo_since', 'promo_time_week'],
#       dtype='object')

# %% [markdown]
# # 4.0 - Passo 4 - ANÁLISE EXPLORATÓRIA DE DADOS

# %%
df4 = df3.copy()

# %% [markdown]
# ## 4.1 Análise Univariada

# %% [markdown]
# ### 4.1.1 Variável Resposta

# %%
sns.distplot(df4['sales'])

# %% [markdown]
# ### 4.1.2 Variável Numérica

# %%
plt.rcParams['figure.figsize'] = (35,16)

# %%
num_attributes.hist(bins=35);

# %% [markdown]
# ### 4.1.3 Variável Categórica

# %%
cat_attributes.head()
# Out:
#   state_holiday store_type assortment   promo_interval month_map
# 0             0          c          a                0       Jul
# 1             0          a          a  Jan,Apr,Jul,Oct       Jul
# 2             0          a          a  Jan,Apr,Jul,Oct       Jul
# 3             0          c          c                0       Jul
# 4             0          a          a                0       Jul

# %%
#state_holiday
df4['state_holiday'].drop_duplicates()
# Out:
# 0            regular day
# 63559     public holiday
# 129424    Easter holiday
# 241126         Christmas
# Name: state_holiday, dtype: object

# %%
#Agora quero contar quantas linhas de venda eu tenho em regularday, public holiday, ...
#Pra ter uma ideia de volume pra saber que tipo de feriado impacta mais na minha variável ...
sns.countplot(df4['state_holiday'])

# %%
#state_holiday
#Eu só enxergo regular day pois ela é muito maior.
#Tenho muito mais dias regulares do que feriados.
#Vou filtrar isso
plt.subplot(1, 2, 1)
a = df4[df4['state_holiday'] != 'regular day']
sns.countplot(a['state_holiday'])

plt.subplot(1, 2, 2)
sns.kdeplot(df4[df4['state_holiday'] == 'public holiday']['sales'], label = 'public holiday', shade = True)
sns.kdeplot(df4[df4['state_holiday'] == 'Easter holiday']['sales'], label = 'Easter holiday', shade = True)
sns.kdeplot(df4[df4['state_holiday'] == 'Christmas']['sales'], label = 'Christmas', shade = True)

# %%
#store_type
df4['store_type'].drop_duplicates()
# Out:
# 0     c
# 1     a
# 12    d
# 84    b
# Name: store_type, dtype: object

# %%
sns.countplot(df4['store_type'])

# %%
sns.kdeplot(df4[df4['store_type'] == 'a']['sales'], label = 'a', shade = True)
sns.kdeplot(df4[df4['store_type'] == 'b']['sales'], label = 'b', shade = True)
sns.kdeplot(df4[df4['store_type'] == 'c']['sales'], label = 'c', shade = True)
sns.kdeplot(df4[df4['store_type'] == 'd']['sales'], label = 'd', shade = True)

# %%
#assortment
df4['assortment'].drop_duplicates()
# Out:
# 0         basic
# 3      extended
# 258       extra
# Name: assortment, dtype: object

# %%
sns.countplot(df4['assortment'])

# %%
sns.kdeplot(df4[df4['assortment'] == 'basic']['sales'], label = 'basic', shade = True)
sns.kdeplot(df4[df4['assortment'] == 'extended']['sales'], label = 'extended', shade = True)
sns.kdeplot(df4[df4['assortment'] == 'extra']['sales'], label = 'extra', shade = True)

# %% [markdown]
# ## 4.2 Análise Bivariada

# %% [markdown]
# ### **4.2.1** Lojas com MAIOR **sortimentos** deveriam **vender** MAIS.
# #### Essa hipótese é FALSA!

# %%
aux1 = df4[['assortment', 'sales']].groupby('assortment').sum().reset_index()
sns.barplot(x='assortment', y='sales', data=aux1)

# %%
#O volume de vendas das lojas que tem assortment basic e extended é parecido.
#As que tem assortment tipo extra, tem volume bem menor.
#Para buscar entender se foi um tipo de loja que vendeu num tempo pretérito, vou fazer um novo filtro
#Soma de número de vendas por lojas assortment por tempo
#Vendas, por Assortment, por Semanas do ano

aux2 = df4[['year_week', 'assortment', 'sales']].groupby(['year_week', 'assortment']).sum().reset_index()
aux2.pivot(index='year_week', columns='assortment', values='sales').plot()
#aux3 = aux2.pivot(index='year_week', columns='assortment', values='sales')
#sns.barplot(x='assortment', y='sales', data=aux1)

# %%
#Vamos saber se o extra tem um comportamento linear. Pra fazer isso eu vou filtrar o aux2 e jogar em aux4
aux4 = aux2[aux2['assortment'] == 'extra']
aux4.pivot(index='year_week', columns='assortment', values='sales').plot()

# %%
aux3.head()
# Out:
# assortment     basic  extended   extra
# year_week
# 2013-00     13434262  12425669  269404
# 2013-01     26007250  22917693  350279
# 2013-02     17970974  16029584  377207
# 2013-03     24392076  21243431  404662
# 2013-04     19972891  18130077  363061

# %% [markdown]
# ### **4.2.2** Lojas com **competidores** MAIS PRÓXIMOS deveriam **vender** MENOS.
# #### Essa hipótese é FALSA!

# %%
#VER QUAL O VOLUME DE VENDAS POR DISTÂNCIA DOS COMPETIDORES
#ver se tem alguma diferença
h2 = df4[['competition_distance', 'sales']].groupby('competition_distance').sum().reset_index()
bins = list(np.arange(0, 20000, 1000))
h2['competiton_distance_binned'] = pd.cut(h2['competition_distance'], bins=bins)

#preciso somar todas as vendas dentro de cada grupo (k, m)
h2_binned = h2[['competiton_distance_binned', 'sales']].groupby('competiton_distance_binned').sum().reset_index()

sns.barplot(x='competiton_distance_binned', y='sales', data=h2_binned);

# %%
#Ver concentração de dados com scatter plot
#Mostrou que a concentração está em até 25Km de distância

h_scatter = df4[['competition_distance', 'sales']].groupby('competition_distance').sum().reset_index()

sns.scatterplot(x='competition_distance', y='sales', data=h_scatter);

# %%
#Gráfico que mostra a força da correlação entre as colunas comparadas no groupby (competition_distance e sales)
h_forca = df4[['competition_distance', 'sales']].groupby('competition_distance').sum().reset_index()

plt.subplot(1, 3, 1)
sns.scatterplot(x='competition_distance', y='sales', data=h_forca);

plt.subplot(1, 3, 2)
bins = list(np.arange(0, 20000, 1000))
h_forca['competiton_distance_binned'] = pd.cut(h_forca['competition_distance'], bins=bins)

#preciso somar todas as vendas dentro de cada grupo (k, m)
h2_binned_forca = h_forca[['competiton_distance_binned', 'sales']].groupby('competiton_distance_binned').sum().reset_index()
sns.barplot(x='competiton_distance_binned', y='sales', data=h2_binned_forca);
plt.xticks(rotation=60);

plt.subplot(1, 3, 3)
sns.heatmap(h_forca.corr(method='pearson'), annot=True);
#x = sns.heatmap(h_forca.corr(method='pearson'), annot=True);
#bottom, top = x.get_ylim()
#x.set_ylim(bottom+0.5, top-0.5);

# %%
h2['competiton_distance_binned'][561:569]
# Out:
# 561    (16000, 17000]
# 562    (16000, 17000]
# 563    (16000, 17000]
# 564    (16000, 17000]
# 565    (16000, 17000]
# 566    (17000, 18000]
# 567    (17000, 18000]
# 568    (17000, 18000]
# Name: competiton_distance_binned, dtype: category
# Categories (19, interval[int64]): [(0, 1000] < (1000, 2000] < (2000, 3000] < (3000, 4000] ... (15000, 16000] < (16000, 17000] < (17000, 18000] < (18000, 19000]]

# %% [markdown]
# ### **4.2.3** Lojas com **competidores** À MAIS TEMPO deveriam **vender** MAIS.
# #### Essa hipótese é falsa!
# #### Quanto mais recente for a minha competição, maiores são as vendas

# %%
#Estamos interessados no tempo desde que a competição começou e como isso influencia nas venda
h3 = df4[['competition_open_since_month', 'sales']].groupby('competition_open_since_month').sum().reset_index()
sns.barplot(x='competition_open_since_month', y='sales', data=h3);

# %%
#O gráfico acima não ajuda muito, pois o que eu quero é:
#qual a relação entre o tempo que o competidor está aberto com as vendas
#se o competidor abriu no mês nove e eu estou vendendo no mês dez faz um mês que ele começou
#se eu estou vendendo no mês nove do ano seguinte faz um ano que ele começou
#o tempo desde que ele começou, como isso influencia nas vendas?
#para isso vamos utilizar a coluna que derivamos a competition_time_month
h3 = df4[['competition_time_month', 'sales']].groupby('competition_time_month').sum().reset_index()
sns.barplot(x='competition_time_month', y='sales', data=h3);

# %%
#por termos muitos meses o gráfico será muito granular.
#vamos criar um filtro para melhorar a visualização
#olharei apenas os primeiros 120 meses de competição, filtrando também os que começaram no mesmo mês da venda != 0
h3 = df4[['competition_time_month', 'sales']].groupby('competition_time_month').sum().reset_index()
h3_filtrado = h3[(h3['competition_time_month'] <= 120) & (h3['competition_time_month'] != 0)]
sns.barplot(x='competition_time_month', y='sales', data=h3_filtrado);
plt.xticks(rotation=60);

# %%
#Vamos medir a força da coluna competition_time_month na sales (variável resposta)
plt.subplot(1, 3, 1)
h3 = df4[['competition_time_month', 'sales']].groupby('competition_time_month').sum().reset_index()
h3_filtrado = h3[(h3['competition_time_month'] <= 120) & (h3['competition_time_month'] != 0)]
sns.barplot(x='competition_time_month', y='sales', data=h3_filtrado);
plt.xticks(rotation=60);

plt.subplot(1, 3, 2)
sns.regplot(x='competition_time_month', y='sales', data=h3_filtrado);

plt.subplot(1, 3, 3)
sns.heatmap(h_forca.corr(method='pearson'), annot=True);
#x = sns.heatmap(h_forca.corr(method='pearson'), annot=True);
#bottom, top = x.get_ylim()
#x.set_ylim(bottom+0.5, top-0.5);

# %%
df4.columns
# Out:
# Index(['store', 'day_of_week', 'date', 'sales', 'promo', 'state_holiday',
#        'school_holiday', 'store_type', 'assortment', 'competition_distance',
#        'competition_open_since_month', 'competition_open_since_year', 'promo2',
#        'promo2_since_week', 'promo2_since_year', 'is_promo', 'year', 'month',
#        'day', 'week_year', 'year_week', 'competition_since',
#        'competition_time_month', 'promo_since', 'promo_time_week'],
#       dtype='object')

# %% [markdown]
# ## 4.3 Análise Multivariada
